# %% [markdown]
# # One Shot Learning with Siamese Networks
#
# This is the jupyter notebook that accompanies

# %% [markdown]
# ## Imports
# All the imports are defined here

# %%
# %matplotlib inline
import torchvision
import torchvision.datasets as dset
import torchvision.transforms as transforms
from torch.utils.data import DataLoader,Dataset
import matplotlib.pyplot as plt
import torchvision.utils
import numpy as np
import random
from PIL import Image
import torch
from torch.autograd import Variable
import PIL.ImageOps    
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
from siamese_dataset import SiameseDataset
import os

# %% [markdown]
# ## Helper functions
# Set of helper functions to visualize data and training curves

# %%
def imshow(img,text=None,should_save=False):
    npimg = img.numpy()
    plt.axis("off")
    if text:
        plt.text(75, 8, text, style='italic',fontweight='bold',
            bbox={'facecolor':'white', 'alpha':0.8, 'pad':10})
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()    

def show_plot(train_losses, val_losses):
    
    x = list(range(len(train_losses)))
    fig, (ax1, ax2) = plt.subplots(2)
    fig.suptitle('Train and Val Losses')
    ax1.plot(x, train_losses)
    ax2.plot(x, val_losses)
    plt.savefig('train_val_loss.png')
    plt.show()

# %% [markdown]
# ## Configuration Class
# A simple class to manage configuration

# %%
class Config():
    training_dir = "./address_gram_images_with_background/train/"
    val_dir = "./address_gram_images_with_background/val/"
    test_dir = "./address_gram_images_with_background/test/"
    
    train_batch_size = 64
    train_number_epochs = 60

# %% [markdown]
# ## Custom Dataset Class
# This dataset generates a pair of images. 0 for geniune pair and 1 for imposter pair

# %% [markdown]
# ## Using Image Folder Dataset

# %%
# create image folder objects
train_folder = dset.ImageFolder(root=Config.training_dir)
val_folder = dset.ImageFolder(root=Config.val_dir)
test_folder = dset.ImageFolder(root=Config.test_dir)

# %%
# define transforms
image_size = 128

transform_all = transforms.Compose([transforms.Resize((image_size, image_size)),
                                    transforms.ToTensor()] )  # can potentially change these vals

# %% [markdown]
# # create dataset objects

# %%
train_dataset = SiameseDataset(imageFolderDataset=train_folder,
                                        transform=transform_all,
                                       should_invert=False)
val_dataset = SiameseDataset(imageFolderDataset=val_folder,
                                        transform=transform_all,
                                       should_invert=False)
test_dataset = SiameseDataset(imageFolderDataset=test_folder,
                                        transform=transform_all,
                                       should_invert=False)

# %% [markdown]
# ## Visualising some of the data
# The top row and the bottom row of any column is one pair. The 0s and 1s correspond to the column of the image.
# 1 indiciates dissimilar, and 0 indicates similar.

# %%
vis_dataloader = DataLoader(train_dataset,
                        shuffle=True,
                        num_workers=8,
                        batch_size=8)
dataiter = iter(vis_dataloader)


example_batch = next(dataiter)
concatenated = torch.cat((example_batch[0],example_batch[1]),0)
imshow(torchvision.utils.make_grid(concatenated))
print(example_batch[2].numpy())
# Out:
# [[0.]
#  [1.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]]

# %% [markdown]
# ## Neural Net Definition
# We will use a standard convolutional neural network

# %%
class SiameseNetwork(nn.Module):
    def __init__(self):
        super(SiameseNetwork, self).__init__()
        
        image_size = 128
        fc_dropout_prob = 0.5
        
        self.cnn1 = nn.Sequential(
            nn.Conv2d(1, 8, kernel_size=3, padding=1),
            nn.MaxPool2d(2, 2),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(8),
            
            nn.Conv2d(8, 16, kernel_size=3, padding=1),
            nn.MaxPool2d(2, 2),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(16),
            
            nn.Conv2d(16, 16, kernel_size=3, padding=1),
#             nn.MaxPool2d(2, 2),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(16),
        )

        self.fc1 = nn.Sequential(
            nn.Linear(16*32*32, 3000),  # flatten here
            nn.ReLU(inplace=True),
#             nn.Dropout(p=fc_dropout_prob),

#             nn.Linear(2000, 128),
#             nn.ReLU(inplace=True),
#             nn.Dropout(p=fc_dropout_prob),

            nn.Linear(3000, 500))  # change this output dimension later

    def forward_once(self, x):
        output = self.cnn1(x)
        output = output.view(output.size()[0], -1)
        output = self.fc1(output)
        return output

    def forward(self, input1, input2):
        output1 = self.forward_once(input1)
        output2 = self.forward_once(input2)
        return output1, output2

# %% [markdown]
# ## Contrastive Loss

# %%
class ContrastiveLoss(torch.nn.Module):
    """
    Contrastive loss function.
    Based on: http://yann.lecun.com/exdb/publis/pdf/hadsell-chopra-lecun-06.pdf
    """

    def __init__(self, margin=2.0):
        super(ContrastiveLoss, self).__init__()
        self.margin = margin

    def forward(self, output1, output2, label):
        euclidean_distance = F.pairwise_distance(output1, output2, keepdim = True)
        loss_contrastive = torch.mean((1-label) * torch.pow(euclidean_distance, 2) +
                                      (label) * torch.pow(torch.clamp(self.margin - euclidean_distance, min=0.0), 2))


        return loss_contrastive

# %% [markdown]
# ## Training Time!

# %%
train_dataloader = DataLoader(train_dataset,
                        shuffle=True,
                        num_workers=8,
                        batch_size=Config.train_batch_size)
val_dataloader = DataLoader(val_dataset,
                        shuffle=True,
                        num_workers=8,
                        batch_size=Config.train_batch_size)

# %%
net = SiameseNetwork()

if torch.cuda.is_available():
    net = SiameseNetwork().cuda()
    
criterion = ContrastiveLoss()
optimizer = optim.Adam(net.parameters(), lr = 0.0005, weight_decay=1e-5)

# %%
counter = []
loss_history = [] 
iteration_number= 0

# %% [markdown]
# # Save model dir here

# %%
# make saved_model root
saved_models_dir = './saved_models'
if not os.path.exists(saved_models_dir):
    os.mkdir(saved_models_dir)

# %% [markdown]
# # Start training loop

# %%
train_losses = []
val_losses = []
best_val_loss = None
saving_threshold = 1.01

for epoch in range(0, Config.train_number_epochs):
    
    train_running_batch_loss = 0
    val_running_batch_loss = 0
    
    # train loop
    net.train()  # put in train mode
    for batch_num, batch in enumerate(train_dataloader,0):
        img0, img1 , label = batch  # grab the data from batch

        # place on cuda if available
        if torch.cuda.is_available():
            img0, img1, label = img0.cuda(), img1.cuda() , label.cuda()
            
        optimizer.zero_grad()  # zero grad
        output1, output2 = net(img0, img1)  # forward prop
        train_loss = criterion(output1, output2, label) # calc loss
        train_running_batch_loss += train_loss.item()  # add to running loss
        train_loss.backward()  # backprop
        optimizer.step()  # take step forward

        if batch_num % 20 == 0 :
            print("Epoch {}, step {}/{}, loss {:.3f}".format(epoch, batch_num, len(train_dataloader), train_loss.item()))
            if img0.shape[0] != Config.train_batch_size:
                print('different batch size {}, {}'.format(Config.train_batch_size, img0.shape[0]))
    
    # append avg loss for the epoch
    train_losses.append( train_running_batch_loss / len(train_dataloader) )
        
    # start val loop
    net.eval()  # put in eval mode
    with torch.no_grad():  # turn off gradient tracking
        for batch_num, batch in enumerate(val_dataloader, 0):
            img0, img1, label = batch  # grab the data

            # place on cuda if available
            if torch.cuda.is_available():
                img0, img1 , label = img0.cuda(), img1.cuda() , label.cuda()
                
            output1, output2 = net(img0, img1)  # forward prop
            val_loss = criterion(output1, output2, label) # calc loss
            val_running_batch_loss += val_loss.item()

    # append avg loss for the epoch      
    val_losses.append( val_running_batch_loss / len(val_dataloader) )

    # if model improves save
    if best_val_loss is None or best_val_loss > (saving_threshold * val_losses[-1]):
        print("Model improved...saving")
        
        model_name = '{}.pth'.format(str(val_losses[-1]))
        save_path = os.path.join(saved_models_dir, model_name)
        torch.save(net.state_dict(), save_path)
        best_val_loss = val_losses[-1]
                    
    # print stats on epoch (print the last value appended)
    print('Epoch {}/{}, train loss {:.3f}, val loss {:.3f}'.format(epoch, Config.train_number_epochs, train_losses[-1], val_losses[-1]))
# Out:
# Epoch 0, step 0/63, loss 4.579
# Epoch 0, step 20/63, loss 1.049
# Epoch 0, step 40/63, loss 0.931
# Epoch 0, step 60/63, loss 1.158
# Model improved...saving
# Epoch 0/60, train loss 2.960, val loss 1.085
# Epoch 1, step 0/63, loss 1.125
# Epoch 1, step 20/63, loss 1.152
# Epoch 1, step 40/63, loss 1.173
# Epoch 1, step 60/63, loss 1.128
# Model improved...saving
# Epoch 1/60, train loss 1.124, val loss 1.068
# Epoch 2, step 0/63, loss 1.197
# Epoch 2, step 20/63, loss 1.020
# Epoch 2, step 40/63, loss 1.098
# Epoch 2, step 60/63, loss 1.171
# Epoch 2/60, train loss 1.089, val loss 1.154
# Epoch 3, step 0/63, loss 1.220
# Epoch 3, step 20/63, loss 1.010
# Epoch 3, step 40/63, loss 1.046
# Epoch 3, step 60/63, loss 1.199
# Epoch 3/60, train loss 1.100, val loss 1.080
# Epoch 4, step 0/63, loss 1.097
# Epoch 4, step 20/63, loss 1.016
# Epoch 4, step 40/63, loss 1.100
# Epoch 4, step 60/63, loss 1.115
# Model improved...saving
# Epoch 4/60, train loss 1.091, val loss 0.997
# Epoch 5, step 0/63, loss 1.082
# Epoch 5, step 20/63, loss 1.092
# Epoch 5, step 40/63, loss 1.112
# Epoch 5, step 60/63, loss 1.055
# Epoch 5/60, train loss 1.070, val loss 1.002
# Epoch 6, step 0/63, loss 1.107
# Epoch 6, step 20/63, loss 0.954
# Epoch 6, step 40/63, loss 0.953
# Epoch 6, step 60/63, loss 1.030
# Epoch 6/60, train loss 1.063, val loss 1.080
# Epoch 7, step 0/63, loss 1.264
# Epoch 7, step 20/63, loss 1.026
# Epoch 7, step 40/63, loss 1.077
# Epoch 7, step 60/63, loss 1.152
# Model improved...saving
# Epoch 7/60, train loss 1.067, val loss 0.985
# Epoch 8, step 0/63, loss 1.115
# Epoch 8, step 20/63, loss 1.140
# Epoch 8, step 40/63, loss 0.919
# Epoch 8, step 60/63, loss 1.142
# Epoch 8/60, train loss 1.062, val loss 1.052
# Epoch 9, step 0/63, loss 1.059
# Epoch 9, step 20/63, loss 0.930
# Epoch 9, step 40/63, loss 0.962
# Epoch 9, step 60/63, loss 1.003
# Epoch 9/60, train loss 1.040, val loss 1.037
# Epoch 10, step 0/63, loss 0.997
# Epoch 10, step 20/63, loss 1.007
# Epoch 10, step 40/63, loss 1.087
# Epoch 10, step 60/63, loss 1.048
# Epoch 10/60, train loss 1.032, val loss 1.006
# Epoch 11, step 0/63, loss 0.845
# Epoch 11, step 20/63, loss 0.948
# Epoch 11, step 40/63, loss 1.082
# Epoch 11, step 60/63, loss 0.881
# Epoch 11/60, train loss 1.015, val loss 1.004
# Epoch 12, step 0/63, loss 0.996
# Epoch 12, step 20/63, loss 1.022
# Epoch 12, step 40/63, loss 1.000
# Epoch 12, step 60/63, loss 1.207
# Epoch 12/60, train loss 1.012, val loss 1.091
# Epoch 13, step 0/63, loss 0.960
# Epoch 13, step 20/63, loss 0.975
# Epoch 13, step 40/63, loss 0.908
# Epoch 13, step 60/63, loss 1.047
# Epoch 13/60, train loss 0.999, val loss 0.982
# Epoch 14, step 0/63, loss 1.035
# Epoch 14, step 20/63, loss 1.131
# Epoch 14, step 40/63, loss 1.069
# Epoch 14, step 60/63, loss 0.935
# Epoch 14/60, train loss 0.999, val loss 1.031
# Epoch 15, step 0/63, loss 1.045
# Epoch 15, step 20/63, loss 0.884
# Epoch 15, step 40/63, loss 1.061
# Epoch 15, step 60/63, loss 0.839
# Model improved...saving
# Epoch 15/60, train loss 0.967, val loss 0.973
# Epoch 16, step 0/63, loss 0.959
# Epoch 16, step 20/63, loss 0.852
# Epoch 16, step 40/63, loss 0.964
# Epoch 16, step 60/63, loss 0.963
# Epoch 16/60, train loss 0.956, val loss 1.012
# Epoch 17, step 0/63, loss 0.982
# Epoch 17, step 20/63, loss 1.013
# Epoch 17, step 40/63, loss 0.964
# Epoch 17, step 60/63, loss 1.100
# Epoch 17/60, train loss 0.984, val loss 1.022
# Epoch 18, step 0/63, loss 0.910
# Epoch 18, step 20/63, loss 1.067
# Epoch 18, step 40/63, loss 1.105
# Epoch 18, step 60/63, loss 0.979
# Epoch 18/60, train loss 0.964, val loss 1.009
# Epoch 19, step 0/63, loss 1.018
# Epoch 19, step 20/63, loss 1.046
# Epoch 19, step 40/63, loss 1.035
# Epoch 19, step 60/63, loss 1.034
# Epoch 19/60, train loss 0.955, val loss 1.014
# Epoch 20, step 0/63, loss 0.900
# Epoch 20, step 20/63, loss 0.853
# Epoch 20, step 40/63, loss 0.854
# Epoch 20, step 60/63, loss 0.857
# Epoch 20/60, train loss 0.930, val loss 0.989
# Epoch 21, step 0/63, loss 0.830
# Epoch 21, step 20/63, loss 0.993
# Epoch 21, step 40/63, loss 0.969
# Epoch 21, step 60/63, loss 1.053
# Model improved...saving
# Epoch 21/60, train loss 0.913, val loss 0.935
# Epoch 22, step 0/63, loss 0.902
# Epoch 22, step 20/63, loss 0.859
# Epoch 22, step 40/63, loss 0.785
# Epoch 22, step 60/63, loss 0.817
# Epoch 22/60, train loss 0.871, val loss 0.981
# Epoch 23, step 0/63, loss 0.970
# Epoch 23, step 20/63, loss 0.755
# Epoch 23, step 40/63, loss 0.830
# Epoch 23, step 60/63, loss 1.052
# Epoch 23/60, train loss 0.883, val loss 0.991
# Epoch 24, step 0/63, loss 1.026
# Epoch 24, step 20/63, loss 0.778
# Epoch 24, step 40/63, loss 0.785
# Epoch 24, step 60/63, loss 0.878
# Epoch 24/60, train loss 0.849, val loss 0.966
# Epoch 25, step 0/63, loss 0.818
# Epoch 25, step 20/63, loss 0.896
# Epoch 25, step 40/63, loss 0.657
# Epoch 25, step 60/63, loss 0.744
# Epoch 25/60, train loss 0.850, val loss 0.945
# Epoch 26, step 0/63, loss 0.680
# Epoch 26, step 20/63, loss 0.791
# Epoch 26, step 40/63, loss 0.865
# Epoch 26, step 60/63, loss 0.641
# Epoch 26/60, train loss 0.827, val loss 0.950
# Epoch 27, step 0/63, loss 0.790
# Epoch 27, step 20/63, loss 0.909
# Epoch 27, step 40/63, loss 0.858
# Epoch 27, step 60/63, loss 0.687
# Model improved...saving
# Epoch 27/60, train loss 0.815, val loss 0.918
# Epoch 28, step 0/63, loss 0.788
# Epoch 28, step 20/63, loss 0.724
# Epoch 28, step 40/63, loss 0.661
# Epoch 28, step 60/63, loss 1.002
# Epoch 28/60, train loss 0.794, val loss 0.997
# Epoch 29, step 0/63, loss 0.990
# Epoch 29, step 20/63, loss 0.812
# Epoch 29, step 40/63, loss 0.567
# Epoch 29, step 60/63, loss 0.672
# Epoch 29/60, train loss 0.776, val loss 0.943
# Epoch 30, step 0/63, loss 0.659
# Epoch 30, step 20/63, loss 0.738
# Epoch 30, step 40/63, loss 0.785
# Epoch 30, step 60/63, loss 0.727
# Epoch 30/60, train loss 0.763, val loss 0.958
# Epoch 31, step 0/63, loss 0.844
# Epoch 31, step 20/63, loss 0.714
# Epoch 31, step 40/63, loss 0.737
# Epoch 31, step 60/63, loss 0.877
# Epoch 31/60, train loss 0.733, val loss 0.931
# Epoch 32, step 0/63, loss 0.840
# Epoch 32, step 20/63, loss 0.868
# Epoch 32, step 40/63, loss 0.703
# Epoch 32, step 60/63, loss 0.717
# Epoch 32/60, train loss 0.727, val loss 0.919
# Epoch 33, step 0/63, loss 0.687
# Epoch 33, step 20/63, loss 0.616
# Epoch 33, step 40/63, loss 0.652
# Epoch 33, step 60/63, loss 0.644
# Model improved...saving
# Epoch 33/60, train loss 0.680, val loss 0.875
# Epoch 34, step 0/63, loss 0.714
# Epoch 34, step 20/63, loss 0.861
# Epoch 34, step 40/63, loss 0.576
# Epoch 34, step 60/63, loss 0.751
# Epoch 34/60, train loss 0.692, val loss 0.935
# Epoch 35, step 0/63, loss 0.591
# Epoch 35, step 20/63, loss 0.764
# Epoch 35, step 40/63, loss 0.779
# Epoch 35, step 60/63, loss 0.526
# Epoch 35/60, train loss 0.673, val loss 0.897
# Epoch 36, step 0/63, loss 0.654
# Epoch 36, step 20/63, loss 0.655
# Epoch 36, step 40/63, loss 0.612
# Epoch 36, step 60/63, loss 0.731
# Epoch 36/60, train loss 0.649, val loss 0.993
# Epoch 37, step 0/63, loss 0.753
# Epoch 37, step 20/63, loss 0.760
# Epoch 37, step 40/63, loss 0.693
# Epoch 37, step 60/63, loss 0.717
# Epoch 37/60, train loss 0.647, val loss 0.950
# Epoch 38, step 0/63, loss 0.681
# Epoch 38, step 20/63, loss 0.562
# Epoch 38, step 40/63, loss 0.677
# Epoch 38, step 60/63, loss 0.494
# Epoch 38/60, train loss 0.629, val loss 0.912
# Epoch 39, step 0/63, loss 0.586
# Epoch 39, step 20/63, loss 0.539
# Epoch 39, step 40/63, loss 0.537
# Epoch 39, step 60/63, loss 0.536
# Epoch 39/60, train loss 0.635, val loss 0.883
# Epoch 40, step 0/63, loss 0.718
# Epoch 40, step 20/63, loss 0.626
# Epoch 40, step 40/63, loss 0.660
# Epoch 40, step 60/63, loss 0.476
# Epoch 40/60, train loss 0.608, val loss 0.876
# Epoch 41, step 0/63, loss 0.648
# Epoch 41, step 20/63, loss 0.615
# Epoch 41, step 40/63, loss 0.473
# Epoch 41, step 60/63, loss 0.507
# Epoch 41/60, train loss 0.570, val loss 0.940
# Epoch 42, step 0/63, loss 0.546
# Epoch 42, step 20/63, loss 0.548
# Epoch 42, step 40/63, loss 0.398
# Epoch 42, step 60/63, loss 0.561
# Epoch 42/60, train loss 0.562, val loss 0.981
# Epoch 43, step 0/63, loss 0.770
# Epoch 43, step 20/63, loss 0.511
# Epoch 43, step 40/63, loss 0.340
# Epoch 43, step 60/63, loss 0.401
# Epoch 43/60, train loss 0.557, val loss 0.970
# Epoch 44, step 0/63, loss 0.372
# Epoch 44, step 20/63, loss 0.560
# Epoch 44, step 40/63, loss 0.469
# Epoch 44, step 60/63, loss 0.309
# Epoch 44/60, train loss 0.528, val loss 0.947
# Epoch 45, step 0/63, loss 0.517
# Epoch 45, step 20/63, loss 0.455
# Epoch 45, step 40/63, loss 0.583
# Epoch 45, step 60/63, loss 0.530
# Epoch 45/60, train loss 0.525, val loss 0.878
# Epoch 46, step 0/63, loss 0.497
# Epoch 46, step 20/63, loss 0.504
# Epoch 46, step 40/63, loss 0.481
# Epoch 46, step 60/63, loss 0.629
# Epoch 46/60, train loss 0.515, val loss 1.116
# Epoch 47, step 0/63, loss 0.536
# Epoch 47, step 20/63, loss 0.568
# Epoch 47, step 40/63, loss 0.441
# Epoch 47, step 60/63, loss 0.591
# Epoch 47/60, train loss 0.495, val loss 0.979
# Epoch 48, step 0/63, loss 0.459
# Epoch 48, step 20/63, loss 0.506
# Epoch 48, step 40/63, loss 0.556
# Epoch 48, step 60/63, loss 0.344
# Epoch 48/60, train loss 0.491, val loss 0.981
# Epoch 49, step 0/63, loss 0.504
# Epoch 49, step 20/63, loss 0.497
# Epoch 49, step 40/63, loss 0.538
# Epoch 49, step 60/63, loss 0.446
# Epoch 49/60, train loss 0.494, val loss 0.999
# Epoch 50, step 0/63, loss 0.609
# Epoch 50, step 20/63, loss 0.576
# Epoch 50, step 40/63, loss 0.424
# Epoch 50, step 60/63, loss 0.512
# Epoch 50/60, train loss 0.463, val loss 1.062
# Epoch 51, step 0/63, loss 0.465
# Epoch 51, step 20/63, loss 0.515
# Epoch 51, step 40/63, loss 0.526
# Epoch 51, step 60/63, loss 0.419
# Epoch 51/60, train loss 0.460, val loss 1.194
# Epoch 52, step 0/63, loss 0.390
# Epoch 52, step 20/63, loss 0.395
# Epoch 52, step 40/63, loss 0.491
# Epoch 52, step 60/63, loss 0.471
# Epoch 52/60, train loss 0.461, val loss 1.020
# Epoch 53, step 0/63, loss 0.621
# Epoch 53, step 20/63, loss 0.438
# Epoch 53, step 40/63, loss 0.428
# Epoch 53, step 60/63, loss 0.560
# Epoch 53/60, train loss 0.425, val loss 1.091
# Epoch 54, step 0/63, loss 0.381
# Epoch 54, step 20/63, loss 0.348
# Epoch 54, step 40/63, loss 0.565
# Epoch 54, step 60/63, loss 0.427
# Epoch 54/60, train loss 0.428, val loss 0.999
# Epoch 55, step 0/63, loss 0.321
# Epoch 55, step 20/63, loss 0.407
# Epoch 55, step 40/63, loss 0.496
# Epoch 55, step 60/63, loss 0.456
# Epoch 55/60, train loss 0.432, val loss 1.005
# Epoch 56, step 0/63, loss 0.447
# Epoch 56, step 20/63, loss 0.458
# Epoch 56, step 40/63, loss 0.338
# Epoch 56, step 60/63, loss 0.407
# Epoch 56/60, train loss 0.408, val loss 1.090
# Epoch 57, step 0/63, loss 0.514
# Epoch 57, step 20/63, loss 0.499
# Epoch 57, step 40/63, loss 0.384
# Epoch 57, step 60/63, loss 0.452
# Epoch 57/60, train loss 0.413, val loss 1.150
# Epoch 58, step 0/63, loss 0.389
# Epoch 58, step 20/63, loss 0.381
# Epoch 58, step 40/63, loss 0.347
# Epoch 58, step 60/63, loss 0.216
# Epoch 58/60, train loss 0.404, val loss 1.293
# Epoch 59, step 0/63, loss 0.435
# Epoch 59, step 20/63, loss 0.464
# Epoch 59, step 40/63, loss 0.399
# Epoch 59, step 60/63, loss 0.335
# Epoch 59/60, train loss 0.385, val loss 1.131

# %%
# plot train/val loss
show_plot(train_losses, val_losses)

# %% [markdown]
# # Load weights

# %%
train_net = SiameseNetwork()

# %%
PATH = './saved_models/{}.pth'.format(best_val_loss)

# %%
train_net.load_state_dict(torch.load(PATH))
# Out:
# IncompatibleKeys(missing_keys=[], unexpected_keys=[])

# %% [markdown]
# # Display a batch with similarity score

# %%
display_dataloader = DataLoader(test_dataset, num_workers=6, batch_size=1, shuffle=True)

for i in range(10):
    x0,x1,label2 = next(iter(display_dataloader))
    concatenated = torch.cat((x0,x1),0)
    
    if torch.cuda.is_available():
        output1,output2 = train_net(Variable(x0).cuda(),Variable(x1).cuda())
    else:
        output1,output2 = train_net(Variable(x0),Variable(x1))
    
    print(label2)
    euclidean_distance = F.pairwise_distance(output1, output2)
    imshow(torchvision.utils.make_grid(concatenated),'Dissimilarity: {:.2f}'.format(euclidean_distance.item()))
# Out:
# tensor([[1.]])
# tensor([[1.]])
# tensor([[1.]])
# tensor([[1.]])
# tensor([[0.]])
# tensor([[1.]])
# tensor([[0.]])
# tensor([[0.]])
# tensor([[0.]])
# tensor([[1.]])

# %% [markdown]
# # Evaluate on test data

# %%
# set threshold for true and false matches (over this value is false)
threshold = 1
batch_size = 64
true_accs = []
false_accs = []

test_dataloader = DataLoader(test_dataset, num_workers=6, batch_size=batch_size, shuffle=True)

for batch_num, batch in enumerate(test_dataloader):

    # track number correct for each class
    true_correct = 0
    false_correct = 0
    
    false_wrong = 0
    true_wrong = 0
    
    # retrieve batch data
    x0, x1, labels = batch
    
    if torch.cuda.is_available():
        output0, output1 = train_net(Variable(x0).cuda(),Variable(x1).cuda())
    else:
        output0, output1 = train_net(Variable(x0),Variable(x1))
        
    euclidean_distance = F.pairwise_distance(output0, output1)
    
    # create an array of size batch, of threshold
    thresh_array = np.asarray(euclidean_distance.shape[0] * [threshold])
    
    # check if over threshold
#     pred_bools = np.less(euclidean_distance.data.cpu().numpy(), thresh_array)
    
    # calc counts for each class
    false_count = 0
    true_count =  0
    
#     print('false {} and true {} counts'.format(false_count, true_count))
    
    preds = []

    for j in range(euclidean_distance.shape[0]):

        if euclidean_distance[j] < threshold:
            preds.append(0)
        else:
            preds.append(1)

#     print('len preds', len(preds))
    
    # loop thru all labels 
    for i in range(labels.shape[0]):
        
        label = int(labels[i].item())
        pred = preds[i]

        # track false match predictions
        if label == 1:
            false_count += 1
            # if pred is false, and label is false, add 1
            if pred == label:
                false_correct += 1
#                 print('pred == label!!  and label is 1')
            else:
                false_wrong += 1
        # false match
        else:
            true_count += 1
            # if pred is true, and label is true, add 1
            if pred == label:
                true_correct += 1
#                 print('pred == label!!  and label is 0')

            else:
                true_wrong += 1
                
#     print('true correct count', true_correct)
#     print('true wrong count', true_wrong)
#     print('true count total', true_count)

#     print('false correct count', false_correct)
#     print('false wrong count', false_wrong)
#     print('false count total', false_count)
                
    true_match_acc = (true_correct / true_count)*100 
    false_match_acc = (false_correct / false_count)*100
        
    print('Similar font accuracy {:.2f}%'.format(true_match_acc))
    print('Different font accuracy {:.2f}%'.format(false_match_acc))
            
    # append acc for this batch
    true_accs.append(true_match_acc)
    false_accs.append(false_match_acc)
# Out:
# Similar font accuracy 63.64%
# Different font accuracy 61.29%
# Similar font accuracy 75.00%
# Different font accuracy 60.71%
# Similar font accuracy 74.07%
# Different font accuracy 45.95%
# Similar font accuracy 67.65%
# Different font accuracy 53.33%
# Similar font accuracy 56.67%
# Different font accuracy 55.88%
# Similar font accuracy 63.89%
# Different font accuracy 46.43%
# Similar font accuracy 72.97%
# Different font accuracy 55.56%
# Similar font accuracy 80.95%
# Different font accuracy 48.84%
# Similar font accuracy 79.41%
# Different font accuracy 50.00%
# Similar font accuracy 63.33%
# Different font accuracy 64.71%
# Similar font accuracy 60.53%
# Different font accuracy 73.08%
# Similar font accuracy 55.56%
# Different font accuracy 64.29%
# Similar font accuracy 69.23%
# Different font accuracy 72.00%
# Similar font accuracy 62.86%
# Different font accuracy 51.72%
# Similar font accuracy 71.79%
# Different font accuracy 72.00%
# Similar font accuracy 67.86%
# Different font accuracy 50.00%
# Similar font accuracy 72.41%
# Different font accuracy 57.14%
# Similar font accuracy 74.29%
# Different font accuracy 41.38%
# Similar font accuracy 58.54%
# Different font accuracy 52.17%
# Similar font accuracy 56.67%
# Different font accuracy 52.94%
# Similar font accuracy 69.44%
# Different font accuracy 67.86%
# Similar font accuracy 76.00%
# Different font accuracy 58.97%
# Similar font accuracy 77.78%
# Different font accuracy 64.86%
# Similar font accuracy 71.43%
# Different font accuracy 64.29%

# %%
avg_true_acc = sum(true_accs) / len(true_accs)
print(avg_true_acc)
# Out:
# 68.4149523004802

# %%
avg_false_acc = sum(false_accs) / len(false_accs)
print(avg_false_acc)
# Out:
# 57.72498218467852

# %%
overall = (avg_true_acc + avg_false_acc) / 2

# %%
overall
# Out:
# 63.06996724257935
